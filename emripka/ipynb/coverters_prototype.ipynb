# %%
import pandas as pd
import json

# %%
MP_output_dir = "training/materialsproject_output/"
MP_json_dir = "training/materialsproject_json/"
fname = "Si"

# %%
data_df = pd.read_csv(f"{MP_output_dir}/{fname}.csv")
data_df.head()
# Out:
#   Materials Id Formula Spacegroup  Formation Energy (eV)  E Above Hull (eV)  \
# 0       mp-149      Si       Fd3m                  0.000              0.000
# 1       mp-165      Si    P63/mmc                  0.011              0.011
# 2   mp-1203790      Si    P63/mmc                  0.056              0.056
# 3    mp-971662      Si       Pm3n                  0.062              0.062
# 4   mp-1079297      Si       C2/m                  0.072              0.072
#
#    Band Gap (eV)  Has Bandstructure    Volume  Nsites  Theoretical  Count  \
# 0          0.853               True    40.888       2        False   39.0
# 1          0.514               True    81.735       4        False    NaN
# 2          1.363              False  1601.147      68         True    NaN
# 3          1.317               True  1069.771      46         True    NaN
# 4          0.288               True   169.804       8         True    NaN
#
#    Density (gm/cc) Crystal System  Unnamed: 13
# 0            2.281          cubic          NaN
# 1            2.282      hexagonal          NaN
# 2            1.981      hexagonal          NaN
# 3            2.005          cubic          NaN
# 4            2.197     monoclinic          NaN

# %%
data_df = data_df.drop('Unnamed: 13', axis=1)
data_df.columns = [
    "material_ID",
    "formula",
    "spacegroup",
    "formation_energy__eV",
    "E_above_hull__eV",
    "band_gap__eV",
    "has_bandstructure",
    "volume",
    "Nsites",
    "theoretical",
    "count",
    "density__gm_per_cc",
    "crystal_system",
]
data_df = data_df.set_index('material_ID')
data_df.head()
# Out:
#             formula spacegroup  formation_energy__eV  E_above_hull__eV  \
# material_ID
# mp-149           Si       Fd3m                 0.000             0.000
# mp-165           Si    P63/mmc                 0.011             0.011
# mp-1203790       Si    P63/mmc                 0.056             0.056
# mp-971662        Si       Pm3n                 0.062             0.062
# mp-1079297       Si       C2/m                 0.072             0.072
#
#              band_gap__eV  has_bandstructure    volume  Nsites  theoretical  \
# material_ID
# mp-149              0.853               True    40.888       2        False
# mp-165              0.514               True    81.735       4        False
# mp-1203790          1.363              False  1601.147      68         True
# mp-971662           1.317               True  1069.771      46         True
# mp-1079297          0.288               True   169.804       8         True
#
#              count  density__gm_per_cc crystal_system
# material_ID
# mp-149        39.0               2.281          cubic
# mp-165         NaN               2.282      hexagonal
# mp-1203790     NaN               1.981      hexagonal
# mp-971662      NaN               2.005          cubic
# mp-1079297     NaN               2.197     monoclinic

# %%
data_dic = data_df.to_dict('index')
with open(f"{MP_json_dir}/{fname}.json","w") as file:
    json.dump(data_dic,file,indent=4)
